# %%
from pandas import *
import matplotlib.pyplot as plt
import pandas as pd 
import sys 
import matplotlib
year = [2008,2009,2010,2011,2012,2013,2014,2015]
total = []
win_bat = []
win_cha = []
tie = []

df = pd.read_excel('EASY_IPL.xlsx')
df
# Out:
#      Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0               1  League Match  Apr 18  2008  Bangalore            Kolkata
# 1               2  League Match  Apr 19  2008     Mohali            Chennai
# 2               3  League Match  Apr 19  2008      Delhi          Rajasthan
# 3               4  League Match  Apr 20  2008    Kolkata          Hyderabad
# 4               5  League Match  Apr 20  2008     Mumbai             Mumbai
# ..            ...           ...     ...   ...        ...                ...
# 509           510  League Match  May 17  2015  Hyderabad          Hyderabad
# 510           511   Qualifier 1  May 19  2015     Mumbai             Mumbai
# 511           512    Eliminator  May 20  2015       Pune          Bangalore
# 512           513   Qualifier 2  May 22  2015     Ranchi          Bangalore
# 513           514         Final  May 24  2015    Kolkata             Mumbai
#
# ...

# %%
y_2008 = df[df['Year'] == 2008]
y_2008
# Out:
#     Match_Number           Match    Date  Year      Venue Team_Batting_First  \
# 0              1    League Match  Apr 18  2008  Bangalore            Kolkata
# 1              2    League Match  Apr 19  2008     Mohali            Chennai
# 2              3    League Match  Apr 19  2008      Delhi          Rajasthan
# 3              4    League Match  Apr 20  2008    Kolkata          Hyderabad
# 4              5    League Match  Apr 20  2008     Mumbai             Mumbai
# 5              6    League Match  Apr 21  2008     Jaipur             Punjab
# 6              7    League Match  Apr 22  2008  Hyderabad          Hyderabad
# 7              8    League Match  Apr 23  2008    Chennai            Chennai
# 8              9    League Match  Apr 24  2008  Hyderabad          Hyderabad
# 9             10    League Match  Apr 25  2008     Mohali             Punjab
# 10            11    League Match  Apr 26  2008    Chennai            Kolkata
# ...

# %%
total.append(len(y_2008))
total
# Out:
# 58

# %%
win = y_2008[y_2008['Winning_Team'] == 'FirstBatting']
win
# Out:
#     Match_Number           Match    Date  Year      Venue Team_Batting_First  \
# 0              1    League Match  Apr 18  2008  Bangalore            Kolkata
# 1              2    League Match  Apr 19  2008     Mohali            Chennai
# 7              8    League Match  Apr 23  2008    Chennai            Chennai
# 9             10    League Match  Apr 25  2008     Mohali             Punjab
# 14            15    League Match  Apr 28  2008  Bangalore            Chennai
# 16            17    League Match  Apr 30  2008      Delhi              Delhi
# 17            18    League Match   May 1  2008     Jaipur          Rajasthan
# 20            21    League Match   May 3  2008  Bangalore          Bangalore
# 21            22    League Match   May 3  2008     Mohali             Punjab
# 22            23    League Match   May 4  2008     Mumbai             Mumbai
# 28            29    League Match   May 8  2008    Kolkata            Kolkata
# ...

# %%
win_bat.append(len(win))
win_bat
# Out:
# [22]

# %%
win_bol = y_2008[y_2008['Winning_Team'] == 'Chasing']
win_bol
# Out:
#     Match_Number           Match    Date  Year      Venue Team_Batting_First  \
# 2              3    League Match  Apr 19  2008      Delhi          Rajasthan
# 3              4    League Match  Apr 20  2008    Kolkata          Hyderabad
# 4              5    League Match  Apr 20  2008     Mumbai             Mumbai
# 5              6    League Match  Apr 21  2008     Jaipur             Punjab
# 6              7    League Match  Apr 22  2008  Hyderabad          Hyderabad
# 8              9    League Match  Apr 24  2008  Hyderabad          Hyderabad
# 10            11    League Match  Apr 26  2008    Chennai            Kolkata
# 11            12    League Match  Apr 26  2008  Bangalore          Bangalore
# 12            13    League Match  Apr 27  2008     Mohali              Delhi
# 13            14    League Match  Apr 27  2008     Mumbai             Mumbai
# 15            16    League Match  Apr 29  2008    Kolkata            Kolkata
# ...

# %%
len(win_bol)
# Out:
# 36

# %%
win_cha.append(len(win_bol))
win_cha
# Out:
# [36]

# %%
ma_tie =y_2008[y_2008['Winning_Team'] == 'Match Tie']
ma_tie
# Out:
# Empty DataFrame
# Columns: [Match_Number, Match, Date, Year, Venue, Team_Batting_First, Team_Batting_Second, Bat_First_Runs_Scored, Bat_First_Wickets_Lost, Bat_First_Overs_Consumed, Bat_First_Overs_Allocated, Bat_Second_Runs_Scored, Bat_Second_Wickets_Lost, Bat_Second_Overs_Consumed, Bat_Second_Overs_Allocated, Winner, Winning_Team, Winning_Margin, Win_Type, Bat_First_Run_Rate, Bat_Second_Run_Rate, Balls_Remaining, Bat_First_5_ov_score, Bat_First_5_ov_wkts_lost, Bat_First_10_ov_score, Bat_First_10_ov_wkts_lost, Bat_First_15_ov_score, Bat_First_15_ov_wkts_lost, Bat_First_20_ov_score, Bat_First_20_ov_wkts_lost, Bat_Second_5_ov_score, Bat_Second_5_ov_wkts_lost, Bat_Second_5_ov_Req_RR, Bat_Second_10_ov_score, Bat_Second_10_ov_wkts_lost, Bat_Second_10_ov_Req_RR, Bat_Second_15_ov_score, Bat_Second_15_ov_wkts_lost, Bat_Second_15_ov_Req_RR, Bat_Second_20_ov_score, Bat_Second_20_ov_wkts_lost, Match_Time, Duckworth Lewis Used]
# Index: []
#
# [0 rows x 43 columns]

# %%
len(ma_tie)
tie.append(len(ma_tie))

# %%
total
# Out:
# [58]

# %%
win_bat
# Out:
# [22]

# %%
win_cha
# Out:
# [36]

# %%
tie
# Out:
# [0]

# %%
y_2009 = df[df['Year'] == 2009]
y_2009
# Out:
#      Match_Number           Match    Date  Year           Venue  \
# 58             59    League Match  Apr 18  2009       Cape Town
# 59             60    League Match  Apr 18  2009       Cape Town
# 60             61    League Match  Apr 19  2009       Cape Town
# 61             62    League Match  Apr 19  2009       Cape Town
# 62             63    League Match  Apr 20  2009  Port Elizabeth
# 63             64    League Match  Apr 21  2009          Durban
# 64             65    League Match  Apr 22  2009       Cape Town
# 65             66    League Match  Apr 23  2009          Durban
# 66             67    League Match  Apr 23  2009       Cape Town
# 67             68    League Match  Apr 24  2009          Durban
# 68             69    League Match  Apr 25  2009          Durban
# 69             70    League Match  Apr 26  2009  Port Elizabeth
# 70             71    League Match  Apr 26  2009       Cape Town
# 71             72    League Match  Apr 27  2009          Durban
# ...

# %%
len(y_2009)
# Out:
# 57

# %%
total.append(len(y_2009))
total
# Out:
# [58, 57]

# %%
total
# Out:
# [58, 57]

# %%
win = y_2009[y_2009['Winning_Team'] == 'FirstBatting']
win
# Out:
#      Match_Number         Match    Date  Year           Venue  \
# 58             59  League Match  Apr 18  2009       Cape Town
# 59             60  League Match  Apr 18  2009       Cape Town
# 62             63  League Match  Apr 20  2009  Port Elizabeth
# 64             65  League Match  Apr 22  2009       Cape Town
# 65             66  League Match  Apr 23  2009          Durban
# 68             69  League Match  Apr 25  2009          Durban
# 70             71  League Match  Apr 26  2009       Cape Town
# 72             73  League Match  Apr 27  2009  Port Elizabeth
# 75             76  League Match  Apr 29  2009          Durban
# 77             78  League Match  Apr 30  2009       Centurion
# 78             79  League Match   May 1  2009     East London
# 79             80  League Match   May 1  2009          Durban
# 81             82  League Match   May 2  2009    Johannesburg
# 84             85  League Match   May 4  2009     East London
# ...

# %%
len(win)
# Out:
# 26

# %%
win_bat.append(len(win))
win_bat
# Out:
# [22, 26]

# %%
win_bol = y_2009[y_2009['Winning_Team'] == 'Chasing']
print(win_bol)      

win_cha.append(len(win_bol))
print(win_cha)
# Out:
#      Match_Number           Match    Date  Year           Venue  \
# 60             61    League Match  Apr 19  2009       Cape Town
# 61             62    League Match  Apr 19  2009       Cape Town
# 63             64    League Match  Apr 21  2009          Durban
# 67             68    League Match  Apr 24  2009          Durban
# 69             70    League Match  Apr 26  2009  Port Elizabeth
# 71             72    League Match  Apr 27  2009          Durban
# 73             74    League Match  Apr 28  2009       Centurion
# 74             75    League Match  Apr 29  2009          Durban
# 76             77    League Match  Apr 30  2009       Centurion
# 80             81    League Match   May 2  2009  Port Elizabeth
# 82             83    League Match   May 3  2009  Port Elizabeth
# 83             84    League Match   May 3  2009    Johannesburg
# 86             87    League Match   May 5  2009          Durban
# 88             89    League Match   May 7  2009       Centurion
# ...

# %%
win_cha
# Out:
# [36, 30]

# %%
ma_tie =y_2009[y_2009['Winning_Team'] == 'Match Tie']
ma_tie
# Out:
# Empty DataFrame
# Columns: [Match_Number, Match, Date, Year, Venue, Team_Batting_First, Team_Batting_Second, Bat_First_Runs_Scored, Bat_First_Wickets_Lost, Bat_First_Overs_Consumed, Bat_First_Overs_Allocated, Bat_Second_Runs_Scored, Bat_Second_Wickets_Lost, Bat_Second_Overs_Consumed, Bat_Second_Overs_Allocated, Winner, Winning_Team, Winning_Margin, Win_Type, Bat_First_Run_Rate, Bat_Second_Run_Rate, Balls_Remaining, Bat_First_5_ov_score, Bat_First_5_ov_wkts_lost, Bat_First_10_ov_score, Bat_First_10_ov_wkts_lost, Bat_First_15_ov_score, Bat_First_15_ov_wkts_lost, Bat_First_20_ov_score, Bat_First_20_ov_wkts_lost, Bat_Second_5_ov_score, Bat_Second_5_ov_wkts_lost, Bat_Second_5_ov_Req_RR, Bat_Second_10_ov_score, Bat_Second_10_ov_wkts_lost, Bat_Second_10_ov_Req_RR, Bat_Second_15_ov_score, Bat_Second_15_ov_wkts_lost, Bat_Second_15_ov_Req_RR, Bat_Second_20_ov_score, Bat_Second_20_ov_wkts_lost, Match_Time, Duckworth Lewis Used]
# Index: []
#
# [0 rows x 43 columns]

# %%
tie.append(len(ma_tie))
tie
# Out:
# [0, 0]

# %%
y_2010 = df[df['Year'] == 2010]
y_2010

total.append(len(y_2010))
total
# Out:
# [58, 57, 60, 60]

# %%
total
# Out:
# [58, 57, 60, 60]

# %%
total.pop()
# Out:
# 60

# %%
total
# Out:
# [58, 57, 60]

# %%
win_bat
# Out:
# [22, 26]

# %%
win = y_2010[y_2010['Winning_Team'] == 'FirstBatting']
win

win_bat.append(len(win))
win_bat
# Out:
# [22, 26, 31]

# %%
win_bol = y_2010[y_2010['Winning_Team'] == 'Chasing']
win_bol      

win_cha.append(len(win_bol))
win_cha
# Out:
# [36, 30, 28]

# %%
ma_tie =y_2010[y_2010['Winning_Team'] == 'Match Tied']
ma_tie

len(ma_tie)
tie.append(len(ma_tie))

# %%
tie
# Out:
# [0, 0, 1]

# %%
y_2011 = df[df['Year'] == 2011]
y_2011

total.append(len(y_2011))
total
# Out:
# [58, 57, 60, 72]

# %%
win = y_2011[y_2011['Winning_Team'] == 'FirstBatting']
win

win_bat.append(len(win))
win_bat
# Out:
# [22, 26, 31, 32]

# %%
win_bol = y_2011[y_2011['Winning_Team'] == 'Chasing']
win_bol      

win_cha.append(len(win_bol))
win_cha
# Out:
# [36, 30, 28, 40]

# %%
ma_tie =y_2011[y_2011['Winning_Team'] == 'Match Tied']
ma_tie

tie.append(len(ma_tie))
tie
# Out:
# [0, 0, 1, 0]

# %%
y_2012 = df[df['Year'] == 2012]
y_2012

total.append(len(y_2012))
total
# Out:
# [58, 57, 60, 72, 74]

# %%
win = y_2012[y_2012['Winning_Team'] == 'FirstBatting']
win

win_bat.append(len(win))
win_bat
# Out:
# [22, 26, 31, 32, 34]

# %%
win_bol = y_2012[y_2012['Winning_Team'] == 'Chasing']
win_bol      

win_cha.append(len(win_bol))
win_cha
# Out:
# [36, 30, 28, 40, 40]

# %%
ma_tie =y_2012[y_2012['Winning_Team'] == 'Match Tied']
ma_tie

tie.append(len(ma_tie))
tie
# Out:
# [0, 0, 1, 0, 0]

# %%
y_2013 = df[df['Year'] == 2013]
y_2013

total.append(len(y_2013))
total
# Out:
# [58, 57, 60, 72, 74, 76]

# %%
win = y_2013[y_2013['Winning_Team'] == 'FirstBatting']
win

win_bat.append(len(win))
win_bat
# Out:
# [22, 26, 31, 32, 34, 37]

# %%
win_bol = y_2013[y_2013['Winning_Team'] == 'Chasing']
win_bol      

win_cha.append(len(win_bol))
win_cha
# Out:
# [36, 30, 28, 40, 40, 37]

# %%
ma_tie =y_2013[y_2013['Winning_Team'] == 'Match Tied']
ma_tie

tie.append(len(ma_tie))
tie
# Out:
# [0, 0, 1, 0, 0, 2]

# %%
y_2014 = df[df['Year'] == 2014]
y_2014

total.append(len(y_2014))
total
# Out:
# [58, 57, 60, 72, 74, 76, 60]

# %%
win = y_2014[y_2014['Winning_Team'] == 'FirstBatting']
win

win_bat.append(len(win))
win_bat
# Out:
# [22, 26, 31, 32, 34, 37, 22]

# %%
win_bol = y_2014[y_2014['Winning_Team'] == 'Chasing']
win_bol      

win_cha.append(len(win_bol))
win_cha
# Out:
# [36, 30, 28, 40, 40, 37, 37]

# %%
ma_tie =y_2014[y_2014['Winning_Team'] == 'Match Tied']
ma_tie

tie.append(len(ma_tie))
tie
# Out:
# [0, 0, 1, 0, 0, 2, 1]

# %%
y_2015 = df[df['Year'] == 2015]
y_2015

total.append(len(y_2015))
total
# Out:
# [58, 57, 60, 72, 74, 76, 60, 57]

# %%
win = y_2015[y_2015['Winning_Team'] == 'FirstBatting']
win

win_bat.append(len(win))
win_bat
# Out:
# [22, 26, 31, 32, 34, 37, 22, 32]

# %%
win_bol = y_2015[y_2015['Winning_Team'] == 'Chasing']
win_bol      

win_cha.append(len(win_bol))
win_cha
# Out:
# [36, 30, 28, 40, 40, 37, 37, 24]

# %%
ma_tie =y_2015[y_2015['Winning_Team'] == 'Match Tied']
ma_tie

tie.append(len(ma_tie))
tie
# Out:
# [0, 0, 1, 0, 0, 2, 1, 1]

# %%
finalset = list(zip(year,total,win_bat,win_cha,tie))
finalset
# Out:
# [(2008, 58, 22, 36, 0),
#  (2009, 57, 26, 30, 0),
#  (2010, 60, 31, 28, 1),
#  (2011, 72, 32, 40, 0),
#  (2012, 74, 34, 40, 0),
#  (2013, 76, 37, 37, 2),
#  (2014, 60, 22, 37, 1),
#  (2015, 57, 32, 24, 1)]

# %%
import pandas as pd
df = pd.DataFrame(data = finalset , columns = ['year' , 'total match' , 'Number of matches Team Batting First Won' , 'Number of matches team Chasing Won' , 'Number of times Match Tied'])
df
# Out:
#    year  total match  Number of matches Team Batting First Won  \
# 0  2008           58                                        22
# 1  2009           57                                        26
# 2  2010           60                                        31
# 3  2011           72                                        32
# 4  2012           74                                        34
# 5  2013           76                                        37
# 6  2014           60                                        22
# 7  2015           57                                        32
#
#    Number of matches team Chasing Won  Number of times Match Tied
# 0                                  36                           0
# 1                                  30                           0
# 2                                  28                           1
# 3                                  40                           0
# 4                                  40                           0
# ...
