# %%
from pandas import *
import matplotlib.pyplot as plt
import pandas as pd 
import sys 
import matplotlib

# %%
df = pd.read_excel('EASY_IPL.xlsx')
df
# Out:
#      Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0               1  League Match  Apr 18  2008  Bangalore            Kolkata
# 1               2  League Match  Apr 19  2008     Mohali            Chennai
# 2               3  League Match  Apr 19  2008      Delhi          Rajasthan
# 3               4  League Match  Apr 20  2008    Kolkata          Hyderabad
# 4               5  League Match  Apr 20  2008     Mumbai             Mumbai
# ..            ...           ...     ...   ...        ...                ...
# 509           510  League Match  May 17  2015  Hyderabad          Hyderabad
# 510           511   Qualifier 1  May 19  2015     Mumbai             Mumbai
# 511           512    Eliminator  May 20  2015       Pune          Bangalore
# 512           513   Qualifier 2  May 22  2015     Ranchi          Bangalore
# 513           514         Final  May 24  2015    Kolkata             Mumbai
#
#     Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 0             Bangalore                    222                       3
# 1                Punjab                    240                       5
# 2                 Delhi                    129                       8
# 3               Kolkata                    110                      10
# 4             Bangalore                    165                       6
# ..                  ...                    ...                     ...
# 509              Mumbai                    113                      10
# 510             Chennai                    187                       6
# 511           Rajasthan                    180                       4
# 512             Chennai                    139                       8
# 513             Chennai                    202                       5
#
#      Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# 0                        20.0  ...                    51.0
# 1                        20.0  ...                   110.0
# 2                        20.0  ...                    86.0
# 3                        18.4  ...                    38.0
# 4                        20.0  ...                    76.0
# ..                        ...  ...                     ...
# 509                      20.0  ...                    73.0
# 510                      20.0  ...                    86.0
# 511                      20.0  ...                    68.0
# 512                      20.0  ...                    62.0
# 513                      20.0  ...                    67.0
#
#      Bat_Second_10_ov_wkts_lost  Bat_Second_10_ov_Req_RR  \
# 0                           7.0                     17.2
# 1                           1.0                     13.1
# 2                           1.0                      4.4
# 3                           3.0                      7.3
# 4                           3.0                      9.0
# ..                          ...                      ...
# 509                         0.0                      4.1
# 510                         2.0                     10.2
# 511                         3.0                     11.3
# 512                         3.0                      7.8
# 513                         1.0                     13.6
#
#      Bat_Second_15_ov_score  Bat_Second_15_ov_wkts_lost  \
# 0                      81.0                         9.0
# 1                     165.0                         3.0
# 2                     128.0                         1.0
# 3                      81.0                         4.0
# 4                     118.0                         4.0
# ..                      ...                         ...
# 509                     NaN                         NaN
# 510                   121.0                         6.0
# 511                    92.0                         7.0
# 512                    91.0                         3.0
# 513                   112.0                         4.0
#
#     Bat_Second_15_ov_Req_RR Bat_Second_20_ov_score  \
# 0                      28.4                    NaN
# 1                      15.2                  207.0
# 2                       0.4                    NaN
# 3                       6.0                    NaN
# 4                       9.6                  166.0
# ..                      ...                    ...
# 509                     NaN                    NaN
# 510                    13.4                    NaN
# 511                    17.8                    NaN
# 512                     9.8                  140.0
# 513                    18.2                  161.0
#
#      Bat_Second_20_ov_wkts_lost Match_Time  Duckworth Lewis Used
# 0                           NaN    Evening                   NaN
# 1                           4.0  Afternoon                   NaN
# 2                           NaN    Evening                   NaN
# 3                           NaN  Afternoon                   NaN
# 4                           5.0    Evening                   NaN
# ..                          ...        ...                   ...
# 509                         NaN    Evening                   NaN
# 510                         NaN    Evening                   NaN
# 511                         NaN    Evening                   NaN
# 512                         7.0    Evening                   NaN
# 513                         8.0    Evening                   NaN
#
# [514 rows x 43 columns]

# %%
first = df[df['Bat_First_15_ov_wkts_lost']==2]
first
# Out:
#      Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0               1  League Match  Apr 18  2008  Bangalore            Kolkata
# 16             17  League Match  Apr 30  2008      Delhi              Delhi
# 27             28  League Match   May 8  2008      Delhi              Delhi
# 31             32  League Match  May 11  2008  Hyderabad            Kolkata
# 40             41  League Match  May 18  2008    Kolkata            Kolkata
# ..            ...           ...     ...   ...        ...                ...
# 498           499  League Match   May 9  2015    Kolkata             Punjab
# 501           502  League Match  May 10  2015    Chennai            Chennai
# 502           503  League Match  May 11  2015  Hyderabad          Hyderabad
# 510           511   Qualifier 1  May 19  2015     Mumbai             Mumbai
# 511           512    Eliminator  May 20  2015       Pune          Bangalore
#
#     Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 0             Bangalore                    222                       3
# 16            Bangalore                    191                       5
# 27              Chennai                    187                       5
# 31            Hyderabad                    204                       4
# 40              Chennai                    149                       5
# ..                  ...                    ...                     ...
# 498             Kolkata                    183                       5
# 501           Rajasthan                    157                       5
# 502              Punjab                    185                       5
# 510             Chennai                    187                       6
# 511           Rajasthan                    180                       4
#
#      Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# 0                        20.0  ...                    51.0
# 16                       20.0  ...                    83.0
# 27                       20.0  ...                    98.0
# 31                       20.0  ...                    74.0
# 40                       20.0  ...                     NaN
# ..                        ...  ...                     ...
# 498                      20.0  ...                    74.0
# 501                      20.0  ...                    63.0
# 502                      20.0  ...                    70.0
# 510                      20.0  ...                    86.0
# 511                      20.0  ...                    68.0
#
#      Bat_Second_10_ov_wkts_lost  Bat_Second_10_ov_Req_RR  \
# 0                           7.0                     17.2
# 16                          3.0                     10.9
# 27                          2.0                      9.0
# 31                          4.0                     13.1
# 40                          NaN                      NaN
# ..                          ...                      ...
# 498                         3.0                     11.0
# 501                         3.0                      9.5
# 502                         4.0                     11.6
# 510                         2.0                     10.2
# 511                         3.0                     11.3
#
#      Bat_Second_15_ov_score  Bat_Second_15_ov_wkts_lost  \
# 0                      81.0                         9.0
# 16                    134.0                         3.0
# 27                    142.0                         4.0
# 31                    125.0                         6.0
# 40                      NaN                         NaN
# ..                      ...                         ...
# 498                   136.0                         5.0
# 501                    93.0                         5.0
# 502                   104.0                         6.0
# 510                   121.0                         6.0
# 511                    92.0                         7.0
#
#     Bat_Second_15_ov_Req_RR Bat_Second_20_ov_score  \
# 0                      28.4                    NaN
# 16                     11.6                  181.0
# 27                      9.2                  188.0
# 31                     16.0                  181.0
# 40                      NaN                    NaN
# ..                      ...                    ...
# 498                     9.6                  184.0
# 501                    13.0                  145.0
# 502                    16.4                  180.0
# 510                    13.4                    NaN
# 511                    17.8                    NaN
#
#      Bat_Second_20_ov_wkts_lost Match_Time  Duckworth Lewis Used
# 0                           NaN    Evening                   NaN
# 16                          5.0    Evening                   NaN
# 27                          6.0  Afternoon                   NaN
# 31                          7.0  Afternoon                   NaN
# 40                          NaN  Afternoon                   D/L
# ..                          ...        ...                   ...
# 498                         9.0  Afternoon                   NaN
# 501                         9.0    Evening                   NaN
# 502                         7.0    Evening                   NaN
# 510                         NaN    Evening                   NaN
# 511                         NaN    Evening                   NaN
#
# [101 rows x 43 columns]

# %%
second = first[first['Bat_First_20_ov_score'] - first['Bat_First_15_ov_score'] < 25]
second
# Out:
#      Match_Number         Match    Date  Year   Venue Team_Batting_First  \
# 100           101  League Match  May 14  2009  Durban          Rajasthan
#
#     Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 100              Mumbai                    145                       7
#
#      Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# 100                      20.0  ...                    54.0
#
#      Bat_Second_10_ov_wkts_lost  Bat_Second_10_ov_Req_RR  \
# 100                         3.0                      9.2
#
#      Bat_Second_15_ov_score  Bat_Second_15_ov_wkts_lost  \
# 100                    98.0                         5.0
#
#     Bat_Second_15_ov_Req_RR Bat_Second_20_ov_score  \
# 100                     9.6                  143.0
#
#      Bat_Second_20_ov_wkts_lost Match_Time  Duckworth Lewis Used
# 100                        10.0    Evening                   NaN
#
# [1 rows x 43 columns]

# %%
final=second.loc[:,['Match_Number','Team_Batting_Second','Team_Batting_First','Date']]
final
# Out:
#      Match_Number Team_Batting_Second Team_Batting_First    Date
# 100           101              Mumbai          Rajasthan  May 14
