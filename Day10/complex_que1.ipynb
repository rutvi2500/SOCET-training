# %%
from pandas import *
import matplotlib.pyplot as plt
import pandas as pd 
import sys 
import matplotlib

# %%
df = pd.read_excel('EASY_IPL.xlsx')
df
# Out:
#      Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0               1  League Match  Apr 18  2008  Bangalore            Kolkata
# 1               2  League Match  Apr 19  2008     Mohali            Chennai
# 2               3  League Match  Apr 19  2008      Delhi          Rajasthan
# 3               4  League Match  Apr 20  2008    Kolkata          Hyderabad
# 4               5  League Match  Apr 20  2008     Mumbai             Mumbai
# ..            ...           ...     ...   ...        ...                ...
# 509           510  League Match  May 17  2015  Hyderabad          Hyderabad
# 510           511   Qualifier 1  May 19  2015     Mumbai             Mumbai
# 511           512    Eliminator  May 20  2015       Pune          Bangalore
# 512           513   Qualifier 2  May 22  2015     Ranchi          Bangalore
# 513           514         Final  May 24  2015    Kolkata             Mumbai
#
#     Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 0             Bangalore                    222                       3
# 1                Punjab                    240                       5
# 2                 Delhi                    129                       8
# 3               Kolkata                    110                      10
# 4             Bangalore                    165                       6
# ..                  ...                    ...                     ...
# 509              Mumbai                    113                      10
# 510             Chennai                    187                       6
# 511           Rajasthan                    180                       4
# 512             Chennai                    139                       8
# 513             Chennai                    202                       5
#
#      Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# 0                        20.0  ...                    51.0
# 1                        20.0  ...                   110.0
# 2                        20.0  ...                    86.0
# 3                        18.4  ...                    38.0
# 4                        20.0  ...                    76.0
# ..                        ...  ...                     ...
# 509                      20.0  ...                    73.0
# 510                      20.0  ...                    86.0
# 511                      20.0  ...                    68.0
# 512                      20.0  ...                    62.0
# 513                      20.0  ...                    67.0
#
#      Bat_Second_10_ov_wkts_lost  Bat_Second_10_ov_Req_RR  \
# 0                           7.0                     17.2
# 1                           1.0                     13.1
# 2                           1.0                      4.4
# 3                           3.0                      7.3
# 4                           3.0                      9.0
# ..                          ...                      ...
# 509                         0.0                      4.1
# 510                         2.0                     10.2
# 511                         3.0                     11.3
# 512                         3.0                      7.8
# 513                         1.0                     13.6
#
#      Bat_Second_15_ov_score  Bat_Second_15_ov_wkts_lost  \
# 0                      81.0                         9.0
# 1                     165.0                         3.0
# 2                     128.0                         1.0
# 3                      81.0                         4.0
# 4                     118.0                         4.0
# ..                      ...                         ...
# 509                     NaN                         NaN
# 510                   121.0                         6.0
# 511                    92.0                         7.0
# 512                    91.0                         3.0
# 513                   112.0                         4.0
#
#     Bat_Second_15_ov_Req_RR Bat_Second_20_ov_score  \
# 0                      28.4                    NaN
# 1                      15.2                  207.0
# 2                       0.4                    NaN
# 3                       6.0                    NaN
# 4                       9.6                  166.0
# ..                      ...                    ...
# 509                     NaN                    NaN
# 510                    13.4                    NaN
# 511                    17.8                    NaN
# 512                     9.8                  140.0
# 513                    18.2                  161.0
#
#      Bat_Second_20_ov_wkts_lost Match_Time  Duckworth Lewis Used
# 0                           NaN    Evening                   NaN
# 1                           4.0  Afternoon                   NaN
# 2                           NaN    Evening                   NaN
# 3                           NaN  Afternoon                   NaN
# 4                           5.0    Evening                   NaN
# ..                          ...        ...                   ...
# 509                         NaN    Evening                   NaN
# 510                         NaN    Evening                   NaN
# 511                         NaN    Evening                   NaN
# 512                         7.0    Evening                   NaN
# 513                         8.0    Evening                   NaN
#
# [514 rows x 43 columns]

# %%
first = df[df['Bat_Second_15_ov_wkts_lost']==4]
first
# Out:
#      Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 3               4  League Match  Apr 20  2008    Kolkata          Hyderabad
# 4               5  League Match  Apr 20  2008     Mumbai             Mumbai
# 5               6  League Match  Apr 21  2008     Jaipur             Punjab
# 12             13  League Match  Apr 27  2008     Mohali              Delhi
# 24             25  League Match   May 5  2008  Bangalore          Bangalore
# ..            ...           ...     ...   ...        ...                ...
# 493           494  League Match   May 5  2015     Mumbai              Delhi
# 496           497  League Match   May 7  2015    Kolkata            Kolkata
# 499           500  League Match   May 9  2015     Raipur          Hyderabad
# 505           506  League Match  May 14  2015     Mumbai             Mumbai
# 513           514         Final  May 24  2015    Kolkata             Mumbai
#
#     Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 3               Kolkata                    110                      10
# 4             Bangalore                    165                       6
# 5             Rajasthan                    166                       8
# 12               Punjab                    158                       8
# 24               Punjab                    126                      10
# ..                  ...                    ...                     ...
# 493              Mumbai                    152                       6
# 496               Delhi                    171                       7
# 499               Delhi                    163                       4
# 505             Kolkata                    171                       4
# 513             Chennai                    202                       5
#
#      Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# 3                        18.4  ...                    38.0
# 4                        20.0  ...                    76.0
# 5                        20.0  ...                    87.0
# 12                       20.0  ...                    81.0
# 24                       19.2  ...                    81.0
# ..                        ...  ...                     ...
# 493                      20.0  ...                    61.0
# 496                      20.0  ...                    64.0
# 499                      20.0  ...                    65.0
# 505                      20.0  ...                    74.0
# 513                      20.0  ...                    67.0
#
#      Bat_Second_10_ov_wkts_lost  Bat_Second_10_ov_Req_RR  \
# 3                           3.0                      7.3
# 4                           3.0                      9.0
# 5                           3.0                      8.0
# 12                          3.0                      7.8
# 24                          2.0                      4.6
# ..                          ...                      ...
# 493                         4.0                      9.2
# 496                         1.0                     10.8
# 499                         3.0                      9.9
# 505                         2.0                      9.8
# 513                         1.0                     13.6
#
#      Bat_Second_15_ov_score  Bat_Second_15_ov_wkts_lost  \
# 3                      81.0                         4.0
# 4                     118.0                         4.0
# 5                     142.0                         4.0
# 12                    123.0                         4.0
# 24                    109.0                         4.0
# ..                      ...                         ...
# 493                    99.0                         4.0
# 496                   106.0                         4.0
# 499                   104.0                         4.0
# 505                   122.0                         4.0
# 513                   112.0                         4.0
#
#     Bat_Second_15_ov_Req_RR Bat_Second_20_ov_score  \
# 3                       6.0                    NaN
# 4                       9.6                  166.0
# 5                       5.0                    NaN
# 12                      7.2                  162.0
# 24                      3.6                    NaN
# ..                      ...                    ...
# 493                    10.8                  153.0
# 496                    13.2                  158.0
# 499                    12.0                  157.0
# 505                    10.0                  166.0
# 513                    18.2                  161.0
#
#      Bat_Second_20_ov_wkts_lost Match_Time  Duckworth Lewis Used
# 3                           NaN  Afternoon                   NaN
# 4                           5.0    Evening                   NaN
# 5                           NaN    Evening                   NaN
# 12                          6.0  Afternoon                   NaN
# 24                          NaN    Evening                   NaN
# ..                          ...        ...                   ...
# 493                         5.0    Evening                   NaN
# 496                         6.0    Evening                   NaN
# 499                         4.0    Evening                   NaN
# 505                         7.0    Evening                   NaN
# 513                         8.0    Evening                   NaN
#
# [94 rows x 43 columns]

# %%
second = first [first ['Bat_Second_15_ov_Req_RR']==6.60]
second
# Out:
#      Match_Number         Match    Date  Year    Venue Team_Batting_First  \
# 164           165  League Match  Apr 15  2010  Chennai            Chennai
# 342           343  League Match  Apr 17  2013     Pune          Hyderabad
#
#     Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 164               Delhi                    112                       9
# 342                Pune                    119                       8
#
#      Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# 164                      20.0  ...                    56.0
# 342                      20.0  ...                    65.0
#
#      Bat_Second_10_ov_wkts_lost  Bat_Second_10_ov_Req_RR  \
# 164                         4.0                      5.7
# 342                         3.0                      5.5
#
#      Bat_Second_15_ov_score  Bat_Second_15_ov_wkts_lost  \
# 164                    80.0                         4.0
# 342                    87.0                         4.0
#
#     Bat_Second_15_ov_Req_RR Bat_Second_20_ov_score  \
# 164                     6.6                    NaN
# 342                     6.6                    NaN
#
#      Bat_Second_20_ov_wkts_lost Match_Time  Duckworth Lewis Used
# 164                         NaN    Evening                   NaN
# 342                         NaN  Afternoon                   NaN
#
# [2 rows x 43 columns]

# %%
last =second [second ['Winning_Team']=='FirstBatting']
last
# Out:
#      Match_Number         Match    Date  Year Venue Team_Batting_First  \
# 342           343  League Match  Apr 17  2013  Pune          Hyderabad
#
#     Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 342                Pune                    119                       8
#
#      Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# 342                      20.0  ...                    65.0
#
#      Bat_Second_10_ov_wkts_lost  Bat_Second_10_ov_Req_RR  \
# 342                         3.0                      5.5
#
#      Bat_Second_15_ov_score  Bat_Second_15_ov_wkts_lost  \
# 342                    87.0                         4.0
#
#     Bat_Second_15_ov_Req_RR Bat_Second_20_ov_score  \
# 342                     6.6                    NaN
#
#      Bat_Second_20_ov_wkts_lost Match_Time  Duckworth Lewis Used
# 342                         NaN  Afternoon                   NaN
#
# [1 rows x 43 columns]

# %%
final=last.loc[:,['Match_Number','Team_Batting_Second','Team_Batting_First','Date']]
final
# Out:
#      Match_Number Team_Batting_Second Team_Batting_First    Date
# 342           343                Pune          Hyderabad  Apr 17
